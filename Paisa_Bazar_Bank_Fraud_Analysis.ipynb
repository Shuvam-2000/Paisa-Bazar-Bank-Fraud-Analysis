# %% [markdown]
# <a href="https://colab.research.google.com/github/Shuvam-2000/Paisa-Bazar-Bank-Fraud-Analysis/blob/main/Paisa_Bazar_Bank_Fraud_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Paisa Bazar Bank Fraud Analysis**

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis(EDA)
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
#  This project focuses on analyzing customer credit-related data for Paisabazaar, a financial services platform that helps customers access loans, credit cards, and other banking products. The primary objective is to explore the factors that influence an individual's credit score and develop insights that can support creditworthiness assessment.Using Exploratory Data Analysis techniques, the project examines customer demographics, income levels, loan history, credit card utilization, payment behavior, outstanding debt, and other financial attributes.The analysis aims to understand how different financial behaviors impact credit scores and to uncover key indicators of credit risk. These insights can help financial institutions improve loan approval decisions, minimize default risk, and provide more personalized financial recommendations to customers.The project demonstrates how data-driven analysis can support better credit risk management and contribute to more effective decision-making in the banking and financial services industry.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Shuvam-2000/Paisa-Bazar-Bank-Fraud-Analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **PaisaBazar as a company helps customers find suitable finanacial products such as loans and credit cards. A major challenege in providing good services to customers by evaluating the creditworthiness of the customers accurately. Incorrect assesment of credit scores can lead to poor customer recoomendations, higher loan defaults and financial defaults. Here avaliable data are customer financial information such as income, debt, payment behavior, loan history, and credit utilization is available for analysis. Thus the end goal is to analyze the given customer data and identify the factors which influences the credit scores and helps in better credit risk assement and provode good service to the customers.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this project is to analyze customer credit data to identify individuals with low credit scores and determine the key factors influencing their creditworthiness, such as income level, employment type, region, payment behavior, debt, and credit utilization. The analysis aims to identify customer segments that are more likely to default on loans and uncover patterns associated with poor credit performance. Based on these insights, recommendations will be provided to help financial institutions improve credit risk assessment, make informed loan approval decisions, and offer financial products to customers with a higher probability of timely repayment and better credit scores.Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# display rows and columns
pd.set_option('display.max_columns', None) # None --> All Columns
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
url = 'https://raw.githubusercontent.com/Shuvam-2000/EDA-DATASET/refs/heads/main/dataset.csv'
data = pd.read_csv(url)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head(10)
# Out:
#      ID  Customer_ID  Month             Name   Age          SSN Occupation  \
# 0  5634         3392      1    Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2    Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3    Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4    Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5    Aaron Maashoh  23.0  821000265.0  Scientist
# 5  5639         3392      6    Aaron Maashoh  23.0  821000265.0  Scientist
# 6  5640         3392      7    Aaron Maashoh  23.0  821000265.0  Scientist
# 7  5641         3392      8    Aaron Maashoh  23.0  821000265.0  Scientist
# 8  5646         8625      1  Rick Rothackerj  28.0    4075839.0    Teacher
# 9  5647         8625      2  Rick Rothackerj  28.0    4075839.0    Teacher
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (100000, 28)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
# Visualizing the missing values
missing_values = data.isnull().sum()

plt.figure(figsize=(10, 5))
plt.bar(missing_values.index, missing_values.values, width=0.4)
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.title('Missing Values by Column')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation: The visualization shows that all columns contain 0 missing values, indicating that the dataset is complete and no missing value treatment is required**

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains customer financial and credit-related information used to analyze and classify credit scores. It includes features such as income, occupation, loan details, credit card usage, outstanding debt, payment behavior, and credit history. The target variable is the Credit Score category. The dataset consists of multiple numerical and categorical columns. Initial inspection was performed using methods such as head(), info(), shape(), and checks for missing and duplicate values to understand the structure and quality of the data.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Dataset Describe
data.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Short Description Of The Variables :-**
#
# The dataset consists of 100,000 customer records and 28 variables, which consist of customer information including customer demographics, income details, banking information, credit history, debt, payment behavior, and other financial attributes. These variables are usedfor analyzing the customer's creditworthiness and identify the factors which will influence the credit Score. The Credit Score is the target variable which will be used in the analysis. Below there is a detailed description of the whole dataset where the variable name, data type and description are propely classified for better understanding.
#
# **Table for Classification Of The Dataset :-**
#
# | **Variable Name**        | **Type**                          | **Description**                                                      |
# | ------------------------ | --------------------------------- | -------------------------------------------------------------------- |
# | ID                       | Numerical                         | Unique identifier for each record.                                   |
# | Customer_ID              | Numerical                         | Unique identifier assigned to each customer.                         |
# | Month                    | Numerical                         | Month corresponding to the customer's financial record.              |
# | Name                     | Categorical                       | Name of the customer.                                                |
# | Age                      | Numerical                         | Age of the customer in years.                                        |
# | SSN                      | Numerical                         | Social Security Number or customer identification number.            |
# | Occupation               | Categorical                       | Occupation or profession of the customer.                            |
# | Annual_Income            | Numerical                         | Annual income earned by the customer.                                |
# | Monthly_Inhand_Salary    | Numerical                         | Monthly take-home salary after deductions.                           |
# | Num_Bank_Accounts        | Numerical                         | Number of bank accounts owned by the customer.                       |
# | Num_Credit_Card          | Numerical                         | Number of credit cards held by the customer.                         |
# | Interest_Rate            | Numerical                         | Interest rate applicable to the customer's loans.                    |
# | Num_of_Loan              | Numerical                         | Total number of loans taken by the customer.                         |
# | Type_of_Loan             | Categorical                       | Type(s) of loan(s) held by the customer.                             |
# | Delay_from_due_date      | Numerical                         | Number of days the customer delayed payments beyond the due date.    |
# | Num_of_Delayed_Payment   | Numerical                         | Number of delayed payments made by the customer.                     |
# | Changed_Credit_Limit     | Numerical                         | Change in the customer's credit limit over time.                     |
# | Num_Credit_Inquiries     | Numerical                         | Number of credit inquiries made by the customer.                     |
# | Credit_Mix               | Categorical                       | Combination of different credit products owned by the customer.      |
# | Outstanding_Debt         | Numerical                         | Total outstanding debt owed by the customer.                         |
# | Credit_Utilization_Ratio | Numerical                         | Percentage of available credit currently being utilized.             |
# | Credit_History_Age       | Numerical                         | Length of the customer's credit history.                             |
# | Payment_of_Min_Amount    | Categorical                       | Indicates whether the customer pays the minimum amount due.          |
# | Total_EMI_per_month      | Numerical                         | Total Equated Monthly Installment (EMI) paid by the customer.        |
# | Amount_invested_monthly  | Numerical                         | Amount invested by the customer every month.                         |
# | Payment_Behaviour        | Categorical                       | Customer's repayment and spending behavior.                          |
# | Monthly_Balance          | Numerical                         | Remaining monthly account balance after expenses.                    |
# | Credit_Score         | Categorical | Credit score category of the customer (**Good, Standard, or Poor**). |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in data.columns:
    print(f"{col} (No of Unique Values: {data[col].nunique()})")
    print(data[col].unique())
    print("-" * 40)
# Out:
# ID (No of Unique Values: 100000)
# [  5634   5635   5636 ... 155627 155628 155629]
# ----------------------------------------
# Customer_ID (No of Unique Values: 12500)
# [ 3392  8625 11708 ... 44897 34304 37932]
# ----------------------------------------
# Month (No of Unique Values: 8)
# [1 2 3 4 5 6 7 8]
# ----------------------------------------
# Name (No of Unique Values: 10128)
# ['Aaron Maashoh' 'Rick Rothackerj' 'Langep' ... 'Chris Wickhamm'
#  'Sarah McBridec' 'Nicks']
# ----------------------------------------
# Age (No of Unique Values: 43)
# [23. 28. 34. 54. 55. 21. 31. 33. 30. 24. 44. 45. 40. 41. 32. 35. 36. 39.
#  37. 20. 46. 26. 42. 19. 48. 38. 43. 22. 16. 18. 15. 27. 25. 14. 17. 47.
#  53. 56. 29. 49. 51. 50. 52.]
# ----------------------------------------
# SSN (No of Unique Values: 12500)
# [8.21000265e+08 4.07583900e+06 4.86853974e+08 ... 1.33167738e+08
#  3.13509420e+07 7.87359900e+07]
# ----------------------------------------
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# making a copy of the dataset to keep the original dataset unchanged
data_copy = data.copy()

# %%
# checking the copied data info
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
# dropping the irrelevant columns not required for analysis
data_copy = data_copy.drop(columns=['ID', 'Name', 'SSN'])

# %%
data_copy.columns
# Out:
# Index(['Customer_ID', 'Month', 'Age', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# checking the no of unique values in month column
data_copy['Month'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
# fixing incorrect data types
month_map = {
    1: 'Jan',
    2: 'Feb',
    3: 'Mar',
    4: 'Apr',
    5: 'May',
    6: 'Jun',
    7: 'Jul',
    8: 'Aug'
}

data_copy['Month'] = data_copy['Month'].map(month_map)

# %%
data_copy['Month'].unique()
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug'],
#       dtype=object)

# %%
# converting the dtype(float to int)
int_columns = [
    'Age',
    'Num_Bank_Accounts',
    'Num_Credit_Card',
    'Interest_Rate',
    'Num_of_Loan',
    'Delay_from_due_date',
    'Num_of_Delayed_Payment',
    'Num_Credit_Inquiries',
    'Credit_History_Age'
]

data_copy[int_columns] = data_copy[int_columns].astype(int)

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Customer_ID               100000 non-null  int64
#  1   Month                     100000 non-null  object
#  2   Age                       100000 non-null  int64
#  3   Occupation                100000 non-null  object
#  4   Annual_Income             100000 non-null  float64
#  5   Monthly_Inhand_Salary     100000 non-null  float64
#  6   Num_Bank_Accounts         100000 non-null  int64
#  7   Num_Credit_Card           100000 non-null  int64
#  8   Interest_Rate             100000 non-null  int64
#  9   Num_of_Loan               100000 non-null  int64
#  10  Type_of_Loan              100000 non-null  object
#  11  Delay_from_due_date       100000 non-null  int64
#  12  Num_of_Delayed_Payment    100000 non-null  int64
# ...

# %%
data_copy.head(5)
# Out:
#    Customer_ID Month  Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0         3392   Jan   23  Scientist       19114.12            1824.843333
# 1         3392   Feb   23  Scientist       19114.12            1824.843333
# 2         3392   Mar   23  Scientist       19114.12            1824.843333
# 3         3392   Apr   23  Scientist       19114.12            1824.843333
# 4         3392   May   23  Scientist       19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3                4              3            4
# 1                  3                4              3            4
# 2                  3                4              3            4
# 3                  3                4              3            4
# 4                  3                4              3            4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# ...

# %% [markdown]
# **Checking Invalid Values**

# %%
# fetching the unique values in Age
data_copy['Age'].unique()
# Out:
# array([23, 28, 34, 54, 55, 21, 31, 33, 30, 24, 44, 45, 40, 41, 32, 35, 36,
#        39, 37, 20, 46, 26, 42, 19, 48, 38, 43, 22, 16, 18, 15, 27, 25, 14,
#        17, 47, 53, 56, 29, 49, 51, 50, 52])

# %%
# get the ages < 18
data_copy[data_copy['Age'] < 18]['Age'].value_counts().sort_index()
# Out:
# Age
# 14    1197
# 15    1615
# 16    1505
# 17    1551
# Name: count, dtype: int64

# %%
# checking the credit score of the ages
data_copy[data_copy['Age'] < 18][['Age', 'Credit_Score']]
# Out:
#        Age Credit_Score
# 288     16     Standard
# 289     16     Standard
# 290     16     Standard
# 291     16         Poor
# 292     16         Poor
# ...    ...          ...
# 99803   17     Standard
# 99804   17     Standard
# 99805   17     Standard
# 99806   17     Standard
# 99807   17     Standard
#
# [5868 rows x 2 columns]

# %%
# get the value counts of the credit_score for the ages < 18
data_copy[data_copy['Age'] < 18]['Credit_Score'].value_counts()
# Out:
# Credit_Score
# Standard    3019
# Poor        2643
# Good         206
# Name: count, dtype: int64

# %%
# fetching the unique values in Annual Income
data_copy['Annual_Income'].unique()
# Out:
# array([ 19114.12,  34847.84, 143162.64, ...,  37188.1 ,  20002.88,
#         39628.99])

# %%
# Count how many rows have negative income
(data_copy['Annual_Income'] < 0).sum()
# Out:
# np.int64(0)

# %%
# Total count of how many rows have negative loans
(data_copy['Num_of_Loan'] < 0).sum()
# Out:
# np.int64(0)

# %%
# Total count of how many rows have negative Interest Rate
(data_copy['Interest_Rate'] < 0).sum()
# Out:
# np.int64(0)

# %%
# total count of negative values for monthly balance
(data_copy['Monthly_Balance'] < 0).sum()
# Out:
# np.int64(0)

# %%
# fetch minimum values for monthly balance
data_copy['Monthly_Balance'].min()
# Out:
# 0.0077596647753352

# %%
# checking the credit utilization ration for value excedding above 100
data_copy['Credit_Utilization_Ratio'].describe()
# Out:
# count    100000.000000
# mean         32.285173
# std           5.116875
# min          20.000000
# 25%          28.052567
# 50%          32.305784
# 75%          36.496663
# max          50.000000
# Name: Credit_Utilization_Ratio, dtype: float64

# %%
data_copy.head()
# Out:
#    Customer_ID Month  Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0         3392   Jan   23  Scientist       19114.12            1824.843333
# 1         3392   Feb   23  Scientist       19114.12            1824.843333
# 2         3392   Mar   23  Scientist       19114.12            1824.843333
# 3         3392   Apr   23  Scientist       19114.12            1824.843333
# 4         3392   May   23  Scientist       19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3                4              3            4
# 1                  3                4              3            4
# 2                  3                4              3            4
# 3                  3                4              3            4
# 4                  3                4              3            4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# ...

# %% [markdown]
# **Checking Outliers**

# %%
# plotting a boxplot to check for outliers in Age
plt.figure(figsize=(8, 4))

sns.boxplot(x=data_copy['Age'], color='skyblue', linewidth=1.5)

plt.title("Boxplot of Age", fontsize=14, fontweight='bold')
plt.xlabel("Age", fontsize=12)

plt.tight_layout()
plt.show()

# %%
# calculating the IQR and the upper_bound and the lower_bound for age
Q1 = data_copy['Age'].quantile(0.25)
Q3 = data_copy['Age'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data_copy[(data_copy['Age'] < lower_bound) | (data_copy['Age'] > upper_bound)]

print("Number of Outliers In Age:", outliers.shape[0])
# Out:
# Number of Outliers In Age: 0

# %% [markdown]
# **Observation:- After analyizing with the IQR and boxplot it is observed that the Age variable contains no outliers. Therefore, no outlier treatment was required.**

# %%
# calculating the IQR and the upper_bound and the lower_bound for monthly_income
Q1 = data_copy['Monthly_Inhand_Salary'].quantile(0.25)
Q3 = data_copy['Monthly_Inhand_Salary'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data_copy[(data_copy['Monthly_Inhand_Salary'] < lower_bound) | (data_copy['Monthly_Inhand_Salary'] > upper_bound)]

print("Number of Outliers In Monthly_Inhand_Salary:", outliers.shape[0])
# Out:
# Number of Outliers In Monthly_Inhand_Salary: 2017

# %%
# plotting a boxplot to check for outliers in Monthly Inhand Salary
plt.figure(figsize=(8, 4))

sns.boxplot(x=data_copy['Monthly_Inhand_Salary'], color='skyblue', linewidth=1.5)

plt.title("Boxplot of Monthly_Inhand_Salary", fontsize=14, fontweight='bold')
plt.xlabel("Monthly_Inhand_Salary", fontsize=12)

plt.tight_layout()
plt.show()

# %%
# soritng the outliers for the monthly inhand salary
outliers[['Monthly_Inhand_Salary']].sort_values(by='Monthly_Inhand_Salary', ascending=False)
# Out:
#        Monthly_Inhand_Salary
# 62728           15204.633333
# 62735           15204.633333
# 62734           15204.633333
# 62733           15204.633333
# 62732           15204.633333
# ...                      ...
# 75256           12461.296667
# 75257           12461.296667
# 75258           12461.296667
# 75259           12461.296667
# 75260           12461.296667
#
# [2017 rows x 1 columns]

# %%
# fetching the max value of the Monthly Inhand Salary
data_copy['Monthly_Inhand_Salary'].max()
# Out:
# 15204.633333333331

# %% [markdown]
# **Observation:- The IQR method identified 2017 potential outliers in Monthly_Inhand_Salary, mostly above the upper bound. These values likely represent customers with comparatively higher monthly incomes rather than data entry errors thus there's no further outlier treatment needed**

# %%
# calculating the IQR and the upper_bound and the lower_bound for annual income
Q1 = data_copy['Annual_Income'].quantile(0.25)
Q3 = data_copy['Annual_Income'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data_copy[(data_copy['Annual_Income'] < lower_bound) | (data_copy['Annual_Income'] > upper_bound)]

print("Number of Outliers In Annual_Income:", outliers.shape[0])
# Out:
# Number of Outliers In Annual_Income: 2000

# %%
# plotting a boxplot to check for outliers in Monthly Inhand Salary
plt.figure(figsize=(8, 4))

sns.boxplot(x=data_copy['Annual_Income'], color='skyblue', linewidth=1.5)

plt.title("Boxplot of Annual_Income", fontsize=14, fontweight='bold')
plt.xlabel("Annual_Income", fontsize=12)

plt.tight_layout()
plt.show()

# %%
# soritng the outliers for the annual income
outliers[['Annual_Income']].sort_values(by='Annual_Income', ascending=False)
# Out:
#        Annual_Income
# 15688      179987.28
# 15689      179987.28
# 15690      179987.28
# 15691      179987.28
# 15692      179987.28
# ...              ...
# 61828      150256.72
# 61824      150256.72
# 61825      150256.72
# 61826      150256.72
# 61827      150256.72
#
# [2000 rows x 1 columns]

# %%
outliers['Annual_Income'].max()
# Out:
# 179987.28

# %% [markdown]
# **Observation: The IQR method identified 2,000 potential outliers in the Annual_Income column, primarily above the upper bound. Upon inspection, the maximum annual income was 179987.28, which is a realistic value and does not indicate a data entry error. Therefore, these outliers were retained, as they likely represent genuine high-income customers rather than invalid observations.**

# %%
# calculating the IQR and the upper_bound and the lower_bound for outstanding debt
Q1 = data_copy['Outstanding_Debt'].quantile(0.25)
Q3 = data_copy['Outstanding_Debt'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data_copy[(data_copy['Outstanding_Debt'] < lower_bound) | (data_copy['Outstanding_Debt'] > upper_bound)]

print("Number of Outliers In Outstanding_Debt:", outliers.shape[0])
# Out:
# Number of Outliers In Outstanding_Debt: 5272

# %%
# plotting a boxplot to check for outliers in OutStanding Debt
plt.figure(figsize=(8, 4))

sns.boxplot(x=data_copy['Outstanding_Debt'], color='skyblue', linewidth=1.5)

plt.title("Boxplot of Outstanding_Debt", fontsize=14, fontweight='bold')
plt.xlabel("Outstanding_Debt", fontsize=12)

plt.tight_layout()
plt.show()

# %%
# soritng the outliers for the outstanding debt
outliers[['Outstanding_Debt']].sort_values(by='Outstanding_Debt', ascending=False)
# Out:
#        Outstanding_Debt
# 8736            4998.07
# 8737            4998.07
# 8738            4998.07
# 8739            4998.07
# 8743            4998.07
# ...                 ...
# 57056           4019.02
# 57060           4019.02
# 57061           4019.02
# 57062           4019.02
# 57063           4019.02
#
# [5272 rows x 1 columns]

# %%
# checking the max value
outliers['Outstanding_Debt'].max()
# Out:
# 4998.07

# %% [markdown]
# **Observation:- The IQR method detected 5,272 potential outliers in the Outstanding_Debt column, mostly above the upper bound. The maximum outstanding debt was 4,998.07, which is a realistic value. These outliers likely represent customers with higher debt levels rather than error data. Therefore, no outlier treatment was performed, and the values were retained for further analysis.**

# %%
# calculating the IQR and the upper_bound and the lower_bound for Total_EMI_per_month
Q1 = data_copy['Total_EMI_per_month'].quantile(0.25)
Q3 = data_copy['Total_EMI_per_month'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data_copy[(data_copy['Total_EMI_per_month'] < lower_bound) | (data_copy['Total_EMI_per_month'] > upper_bound)]

print("Number of Outliers In Total_EMI_per_month:", outliers.shape[0])
# Out:
# Number of Outliers In Total_EMI_per_month: 5044

# %%
# plotting a boxplot to check for outliers in OutStanding Debt
plt.figure(figsize=(8, 4))

sns.boxplot(x=data_copy['Total_EMI_per_month'], color='skyblue', linewidth=1.5)

plt.title("Boxplot of Total_EMI_per_month", fontsize=14, fontweight='bold')
plt.xlabel("Total_EMI_per_month", fontsize=12)

plt.tight_layout()
plt.show()

# %%
# checking the max value
outliers['Total_EMI_per_month'].max()
# Out:
# 1779.1032538262775

# %% [markdown]
# **The IQR method identified 5,044 potential outliers in the Total_EMI_per_month column, primarily above the upper bound. The maximum monthly EMI was 1,779, which is a realistic value for customers with higher loans. These outliers are genuine observations rather than data entry errors. Therefore, no outlier treatment was performed, and the values were kept for further analysis.**

# %%
# calculating the IQR and the upper_bound and the lower_bound for Credit_Utilization_Ratio
Q1 = data_copy['Credit_Utilization_Ratio'].quantile(0.25)
Q3 = data_copy['Credit_Utilization_Ratio'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data_copy[(data_copy['Credit_Utilization_Ratio'] < lower_bound) | (data_copy['Credit_Utilization_Ratio'] > upper_bound)]

print("Number of Outliers In Credit_Utilization_Ratio:", outliers.shape[0])
# Out:
# Number of Outliers In Credit_Utilization_Ratio: 4

# %%
# plotting a boxplot to check for outliers in Credit_Utilization_Ratio
plt.figure(figsize=(8, 4))

sns.boxplot(x=data_copy['Credit_Utilization_Ratio'], color='skyblue', linewidth=1.5)

plt.title("Boxplot of Credit_Utilization_Ratio", fontsize=14, fontweight='bold')
plt.xlabel("Credit_Utilization_Ratio", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:- The IQR method detected 4 potential outliers in the Credit_Utilization_Ratio column. Upon inspection, the values were found to be within a realistic range and did not indicate any data quality issues. Therefore, the outliers were retained for further analysis**

# %% [markdown]
# **Check Inconsistent Categorical Values**

# %%
# fetch all the unique values for the categorical columns
categorical_columns = [
    'Occupation',
    'Type_of_Loan',
    'Credit_Mix',
    'Payment_of_Min_Amount',
    'Payment_Behaviour',
    'Credit_Score'
]

for col in categorical_columns:
    print(col)
    print(data_copy[col].unique())
    print("-" * 50)
# Out:
# Occupation
# ['Scientist' 'Teacher' 'Engineer' 'Entrepreneur' 'Developer' 'Lawyer'
#  'Media_Manager' 'Doctor' 'Journalist' 'Manager' 'Accountant' 'Musician'
#  'Mechanic' 'Writer' 'Architect']
# --------------------------------------------------
# Type_of_Loan
# ['Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan'
#  'Credit-Builder Loan' 'Auto Loan, Auto Loan, and Not Specified' ...
#  'Home Equity Loan, Auto Loan, Auto Loan, and Auto Loan'
#  'Payday Loan, Student Loan, Mortgage Loan, and Not Specified'
#  'Personal Loan, Auto Loan, Mortgage Loan, Student Loan, and Student Loan']
# --------------------------------------------------
# Credit_Mix
# ['Good' 'Standard' 'Bad']
# --------------------------------------------------
# Payment_of_Min_Amount
# ['No' 'NM' 'Yes']
# --------------------------------------------------
# Payment_Behaviour
# ['High_spent_Small_value_payments' 'Low_spent_Large_value_payments'
# ...

# %%
# value counts of all the items in the payment min amount column
data_copy['Payment_of_Min_Amount'].value_counts()
# Out:
# Payment_of_Min_Amount
# Yes    52326
# No     35667
# NM     12007
# Name: count, dtype: int64

# %%
# replace 'NM' with Not Mentioned in the payment_min_amount column
data_copy['Payment_of_Min_Amount'] = data_copy['Payment_of_Min_Amount'].replace('NM', 'Not Mentioned')

# %%
data_copy['Payment_of_Min_Amount'].value_counts()
# Out:
# Payment_of_Min_Amount
# Yes              52326
# No               35667
# Not Mentioned    12007
# Name: count, dtype: int64

# %% [markdown]
# **Check Impossible Combinaions**

# %%
data_copy[(data_copy['Num_of_Loan'] == 0) & (data_copy['Outstanding_Debt'] > 0)]
# Out:
#        Customer_ID Month  Age Occupation  Annual_Income  \
# 32            7387   Jan   21  Developer       35547.71
# 33            7387   Feb   21  Developer       35547.71
# 34            7387   Mar   21  Developer       35547.71
# 35            7387   Apr   21  Developer       35547.71
# 36            7387   May   21  Developer       35547.71
# ...            ...   ...  ...        ...            ...
# 99939        44367   Apr   47  Developer       22620.79
# 99940        44367   May   47  Developer       22620.79
# 99941        44367   Jun   47  Developer       22620.79
# 99942        44367   Jul   48  Developer       22620.79
# 99943        44367   Aug   48  Developer       22620.79
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 32               2853.309167                  7                5
# 33               2853.309167                  7                5
# 34               2853.309167                  7                5
# ...

# %%
data_copy[(data_copy['Num_of_Loan'] == 0) & (data_copy['Outstanding_Debt'] > 0)].shape[0]
# Out:
# 11408

# %%
data_copy[(data_copy['Num_of_Loan'] == 0) & (data_copy['Outstanding_Debt'] > 0)][['Outstanding_Debt']].describe()
# Out:
#        Outstanding_Debt
# count      11408.000000
# mean         766.436206
# std          431.950674
# min            0.770000
# 25%          404.440000
# 50%          769.985000
# 75%         1138.970000
# max         1496.620000

# %% [markdown]
# **Observation: A total of 11,408 records were identified where Num_of_Loan was 0 while Outstanding_Debt was greater than 0. Although this initially appears inconsistent, outstanding debt can arise from sources other than active loans, such as credit card balances or other credit obligations. As the dataset does not specify the exact source of the debt, these records were retained and documented as a potential business-related inconsistency rather than a data quality error.**

# %%
data_copy[(data_copy['Annual_Income'] > 0) & (data_copy['Monthly_Inhand_Salary'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []

# %%
data_copy[(data_copy['Num_of_Loan'] == 0) & (data_copy['Total_EMI_per_month'] > 0)].head()
# Out:
#      Customer_ID Month  Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 147        13651   Apr   26   Musician       97791.42            7449.469347
# 148        13651   May   26   Musician       97791.42            7449.469347
# 149        13651   Jun   26   Musician       97791.42            7449.469347
# 150        13651   Jul   26   Musician       97791.42            7449.469347
# 151        13651   Aug   26   Musician       97791.42            7449.469347
#
#      Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 147                  6                6             12            0
# 148                  6                6             12            0
# 149                  6                6             12            0
# 150                  6                6             12            0
# 151                  6                6             12            0
#
#     Type_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# ...

# %%
data_copy[(data_copy['Num_of_Loan'] == 0) &
          (data_copy['Total_EMI_per_month'] > 0)].shape[0]
# Out:
# 423

# %%
data_copy[(data_copy['Num_of_Loan'] == 0) &
          (data_copy['Total_EMI_per_month'] > 0)][['Total_EMI_per_month']].describe()
# Out:
#        Total_EMI_per_month
# count           423.000000
# mean            573.593254
# std             416.407752
# min              84.220880
# 25%             244.418400
# 50%             426.048306
# 75%             871.650888
# max            1775.000000

# %% [markdown]
# **Observation: A total of 423 records were identified where the Num_of_Loan was 0 while Total_EMI_per_month was greater than 0. Although this appears inconsistent under normal banking assumptions, the EMI values are realistic. Due to the lack of sufficient evidence to classify these records as erroneous, they were retained and documented as a potential data quality issue.**

# %%
data_copy[(data_copy['Outstanding_Debt'] == 0) &
          (data_copy['Num_of_Delayed_Payment'] > 0)]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ### Data Manipulations Performed
# - Created a copy of the original dataset to preserve the raw data during preprocessing.
# - Removed unnecessary columns (ID, Name, and SSN) as they did not contribute to the analysis.
# - Verified that the dataset contained no missing values and no duplicate records.
# - Converted the Month column from numeric values to month names (Jan – Aug) to improve readability.
# - Converted appropriate numerical columns from float to int where the values represented whole numbers.
# - Standardized the Payment_of_Min_Amount column by replacing NM with Not Mentioned.
# - Validated numerical columns by checking for invalid values such as negative income, negative loans, negative balances, and credit utilization values greater than 100%.
# - Identified potential outliers using Boxplots and the Interquartile Range (IQR) method.
# - Checked categorical variables for inconsistent values, spellings, and formatting.
# - Performed business rule validation to identify potentially inconsistent combinations between related variables.
#
# ### Key Insights
#
# - The dataset was well-structured, containing no missing values or duplicate records.
# - No invalid values were detected in the major numerical variables.
# - Outliers were identified in variables such as **Annual Income**, **Monthly In-hand Salary**, **Outstanding Debt**, and **Total EMI per Month**. These values were found to be realistic financial observations and were therefore retained.
# - The categorical variables were generally consistent, with only the Payment_of_Min_Amount column requiring standardization.
# - A small number of records showed potential business inconsistencies (e.g., customers with zero loans but positive EMI or outstanding debt). These records were retained as they may represent valid financial scenarios or characteristics of the dataset.
# - Overall, the dataset required minimal preprocessing and was found to be suitable for exploratory data analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10, 5))

sns.histplot(
    data=data_copy,
    x='Annual_Income',
    bins=25,
    kde=True,
    color='red',
    edgecolor='black'
)

plt.title("Distribution of Annual Income", fontsize=16, fontweight='bold')
plt.xlabel("Annual Income", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram is used here to visualize the Annual_Income as first it's a numerical variable. The histogram here helps understanding the distribution of the frequency of cusotmer annual income values by identifying the overall distribution pattern and observing how customer income are spread across different income ranges

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram indicates that the Annual_Income variable is positively (right) skewed. A large proportion of customers have annual incomes concentrated between approximately 10,000 and 50,000, while the frequency of customers steadily decreases as income increases. The long right tail shows that a relatively small number of customers earn significantly higher annual incomes, extending up to around 180,000. This suggests that high-income customers are less common but contribute to the overall variability of the dataset.The distribution exhibits slight fluctuations and multiple local peaks, suggesting the presence of different income groups within the customer population.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights For positive business impacts:-
#
# `-` The distribution of annual income helps identify the income profile of the customer base. Since most customers fall within the lower and middle income ranges, financial institutions can design products such as affordable loans, credit cards, and EMI plans that better match their repayment capacity.
#
# `-` The smaller segment of high-income customers can be targeted with premium banking services, higher credit limits, and exclusive financial products, enabling more effective customer segmentation and personalized marketing strategies.
#
# Insights For Negative Growth:-
#
# For negative impact there are no direct negative business impact observed. However the aligining of maximum customers in the income range of 10,000 - 50,000 and a small porportion of customer in the high income range may limit the market for premium finanacial product and services, as the majority of customers have moderate incomes. Businesses should therefore focus on products and services tailored to the larger lower- and middle-income customer segments to maximize customer engagement and profitability.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8, 5))

sns.countplot(
    data=data_copy,
    x='Credit_Score',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    edgecolor='black',
    linewidth=1.2
)

plt.title("Distribution of Credit Score", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Number of Customers", fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot was chosen because Credit_Score is a categorical variable. It is the most appropriate chart for displaying the frequency of each credit score category, allowing for an easy comparison of the number of customers with Poor, Standard, and Good credit scores. This helps identify the most and least common credit score categories within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The countplot shows that the majority of customers fall under the Standard credit score category, indicating that most customers have an average credit profile. Customers with a Poor credit score form the second-largest group, while those with a Good credit score are comparatively fewer.The dominance of the Standard credit score category may also be associated with the larger proportion of customers belonging to the lower and middle income groups, as observed in the annual income distribution. This distribution suggests that there is significant scope for financial institutions to improve customer creditworthiness through effective credit management strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights For positive business impacts:-
#
# `-` The insights indicate that the majority of customers belong to the Standard credit score category. Financial institutions can use this information to design effective credit management strategies focused on this customer segment, such as personalized repayment plans, financial literacy programs, and responsible credit offerings to improve their creditworthiness over time.
#
# `-` For customers with a Good credit score, institutions can offer premium financial products, higher credit limits, lower interest rates, and exclusive banking services to strengthen customer loyalty and increase profitability.
#
# Insights For Negative Growth:-
#
# `-` A considerable proportion of customers fall into the Poor credit score category, which may increase the risk of loan defaults, delayed repayments, and higher credit losses for financial institutions.
#
# `-` The relatively smaller number of customers in the Good credit score category limits the potential market for premium financial products and services.
#
# `-` Financial institutions should focus on improving the credit profiles of customers in the Poor and Standard categories through effective credit risk management and customer engagement strategies.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Annual_Income vs Credit_Score(Numerical & Categorical)
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=data_copy,
    x='Credit_Score',
    y='Annual_Income',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    linewidth=1.5,
    width=0.55,
)

plt.title("Annual Income Distribution Across Credit Score Categories",
          fontsize=16, fontweight='bold', pad=15)

plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Annual Income", fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.3)

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it is the most appropriate visualization for comparing the distribution of a numerical variable (Annual_Income) across different categories of a categorical variable (Credit_Score). It clearly displays the median, interquartile range (IQR), overall spread, and potential outliers for each credit score category. This makes it easy to compare income distributions among customers with Poor, Standard, and Good credit scores and identify differences in their income levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The boxplot shows that customers with a Good credit score generally have a higher median annual income than those with Standard and Poor credit scores. The Poor credit score category exhibits a large number of high-income outliers, indicating that some customers with high annual incomes still have poor credit scores.The spread of annual income increases from the Poor to the Good credit score category, indicating greater income variability among customers with better credit scores. The presnece of higher number of outliers in the Poor credit score indicates that higher income alone dosen't define a customers overall credit score and there are other factors which influence it.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Postitve Business Insights:-
#
# `-` Customers with a Good credit score generally have a higher median annual income, making them suitable candidates for premium financial products, higher credit limits, and exclusive banking services.
#
# `-` Financial institutions can design customer-specific loan and credit card offerings based on different credit score categories
#
# `-` Customers in the Standard category can be targeted with credit improvement programs, financial education, and personalized repayment plans to help them achieve a better credit score.
#
# `-` The analysis shows that annual income alone does not determine creditworthiness, encouraging institutions to consider multiple financial factors before making lending decisions, resulting in more effective risk assessment.
#
# Negative Insghts:-
#
# `-` The Poor credit score category contains a large number of customers, increasing the risk of loan defaults, delayed repayments, and higher credit losses.
#
# `-` The presence of high-income customers with Poor credit scores indicates that a higher income does not necessarily translate into better credit behavior. Relying solely on income for lending decisions may therefore increase financial risk.
#
# `-` The smaller proportion of customers with Good credit scores limits the market for premium financial products and services, potentially affecting revenue growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Occupation Vs Credit_Score
plt.figure(figsize=(10, 7))

sns.countplot(
    data=data_copy,
    y='Occupation',
    hue='Credit_Score',
    hue_order=['Poor', 'Standard', 'Good'],
    palette='Set2'
)

plt.title("Credit Score Distribution Across Occupations")
plt.xlabel("Number of Customers")
plt.ylabel("Occupation")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped countplot was chosen because both Occupation and Credit_Score are categorical variables. It is the most suitable visualization for comparing the frequency of each credit score category across different occupations. The chart enables easy comparison of the distribution of Poor, Standard, and Good credit scores within each occupation, helping identify patterns and differences among occupational groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights Found :-
#
# - The **Standard** credit score category has the highest number of customers across almost all occupations, indicating that the majority of customers, regardless of their profession, possess an average credit profile.
#
# - The **Poor** credit score category consistently has the second-highest number of customers, while the **Good** credit score category has the lowest number of customers across most occupations.
#
# - The distribution of credit scores is fairly similar across different occupations, suggesting that **occupation alone does not have a significant influence on a customer's credit score**.
#
# - The absence of a dominant **Good** credit score category within any particular occupation indicates that other financial factors, such as **annual income, repayment history, outstanding debt, credit utilization ratio, and delayed payments**, are likely to have a greater impact on determining a customer's creditworthiness than occupation alone.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights for positive business impact:-
#
# - Since the majority of customers across all occupations belong to the **Standard** credit score category, financial institutions can develop customer-centric credit management strategies targeted at this segment to improve their creditworthiness.
#
# - Occupation-based customer segmentation can help institutions design personalized financial products, loan offers, and marketing campaigns that better meet the needs of different professional groups.
#
# - As no single occupation is dominated by the **Good** credit score category, financial institutions should evaluate customers using multiple financial indicators rather than relying solely on occupation, leading to more accurate credit risk assessment and lending decisions.
#
# Insights for negative growth:-
#
# - The relatively high number of customers with **Poor** credit scores across all occupations may increase the risk of loan defaults, delayed repayments, and higher credit losses.
#
# - Since occupation alone does not show a strong relationship with credit score, making lending decisions based primarily on a customer's profession may result in inaccurate credit risk assessment and poor business decisions.
#
# - Financial institutions should therefore incorporate additional factors such as annual income, repayment history, outstanding debt, credit utilization ratio, and delayed payments to improve the accuracy of credit evaluation and minimize financial risk.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Outstanding Debt vs Credit Score
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=data_copy,
    x='Credit_Score',
    y='Outstanding_Debt',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    linewidth=1.5,
    width=0.55,
)

plt.title(
    "Outstanding Debt Distribution Across Credit Score Categories",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Outstanding Debt", fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it effectively compares the distribution of Outstanding_Debt across the three credit score categories (Poor, Standard, and Good). It clearly displays the median, interquartile range (IQR), overall spread, and potential outliers for each category, making it easier to identify differences in debt levels among customers with different credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights Found:-
#
# - Customers with a **Poor** credit score have the **highest median outstanding debt**, indicating that they generally carry more debt than customers in the other credit score categories.
#
# - Customers with a **Standard** credit score have a **moderate level of outstanding debt**. This category also contains a large number of high-debt outliers, suggesting that some customers maintain significantly higher debt levels despite having an average credit score.
#
# - Customers with a **Good** credit score have the **lowest median outstanding debt**, indicating that they generally manage lower debt levels compared to the other two categories.
#
# - Although the **Standard** and **Good** credit score categories also contain several high-debt outliers, the overall distribution shows that customers with **Good** credit scores tend to have lower outstanding debt. This suggests that **outstanding debt is an important factor influencing credit scores, but it is not the only determining factor**, as other financial variables may also contribute to a customer's overall creditworthiness.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact:-
#
# - The analysis provides a clear understanding of the outstanding debt distribution across different credit score categories, enabling financial institutions to effectively segment customers and offer personalized financial products and services.
#
# - Since the **Standard** credit score category contains the largest customer base, financial institutions can primarily focus on this segment by providing financial education, credit improvement programs, and personalized repayment plans to enhance customers' creditworthiness.
#
# - Customers with **Good** credit scores generally have lower outstanding debt, making them suitable candidates for premium banking services, higher credit limits, lower interest rates, and exclusive financial products.
#
# - Understanding the debt distribution also helps financial institutions perform better credit risk assessment and make more informed lending decisions.
#
# ### Insights that lead to negative growth:-
#
# - The **Standard** credit score category contains a considerable number of high outstanding debt outliers. This indicates that customers within the same credit score category may have significantly different debt profiles, making customer segmentation more challenging.
#
# - Relying solely on outstanding debt while evaluating customers may lead to inaccurate credit risk assessment, as customers with similar debt levels can still have different credit scores.
#
# - Financial institutions should therefore consider additional factors such as repayment history, credit utilization ratio, annual income, delayed payments, and credit inquiries alongside outstanding debt to make more accurate lending decisions and reduce financial risk.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Payment Behaviour vs Credit Score
plt.figure(figsize=(11, 6))

sns.countplot(
    data=data_copy,
    y='Payment_Behaviour',
    hue='Credit_Score',
    hue_order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    edgecolor='black',
    linewidth=1
)

plt.title(
    "Credit Score Distribution Across Payment Behaviour",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Number of Customers", fontsize=12, fontweight='bold')
plt.ylabel("Payment Behaviour", fontsize=12, fontweight='bold')
plt.grid(axis='x', linestyle='--', alpha=0.3)
plt.legend(title='Credit Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped countplot was chosen because both Payment_Behaviour and Credit_Score are categorical variables. It effectively compares the frequency of Poor, Standard, and Good credit score categories across different payment behaviours, making it easier to identify patterns and relationships between customers' payment behaviour and their credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights Found:-
#
# - Across all payment behaviour categories, the **Standard** credit score has the highest number of customers, indicating that the majority of customers exhibit an average credit profile regardless of their spending and payment behaviour.
#
# - The **Poor** credit score category consistently has the second-highest number of customers, while the **Good** credit score category has the lowest number of customers across all payment behaviour groups.
#
# - Customers with **Low_spent_Small_value_payments** have the highest number of customers in both the **Standard** and **Poor** credit score categories, suggesting that this payment behaviour is the most common among customers in the dataset.
#
# - The **Good** credit score category is comparatively lower across all payment behaviour groups, indicating that fewer customers maintain a good credit profile regardless of their payment behaviour.
#
# - Although payment behaviour shows some variation across credit score categories, the dominance of the **Standard** credit score category suggests that payment behaviour alone is not sufficient to determine a customer's creditworthiness. Other financial factors such as **annual income, outstanding debt, credit utilization ratio, repayment history, and delayed payments** are also likely to influence the overall credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact:-
#
# - The chart clearly shows that customers with a **Standard** credit score form the largest customer segment across all payment behaviour categories. This enables financial institutions to focus on this group by providing customer-centric credit management strategies, financial education, and personalized repayment plans to improve their creditworthiness.
#
# - The comparatively smaller number of customers with a **Good** credit score allows financial institutions to easily identify and segment these customers for premium banking services, higher credit limits, exclusive financial products, and loyalty programs.
#
# - The chart also helps identify customers with **Poor** credit scores, allowing financial institutions to perform stricter credit risk assessments before approving loans, credit cards, or other financial services.
#
# - Overall, the analysis supports better customer segmentation, targeted marketing, and more informed lending decisions based on customers' payment behaviour and credit profiles.
#
#
# ### Insights that lead to negative growth:-
#
# - Customers with **Low_spent_Small_value_payments** have the highest number of both **Standard** and **Poor** credit scores. This indicates that payment behaviour alone is not sufficient to accurately determine a customer's creditworthiness.
#
# - Relying solely on payment behaviour for lending decisions may result in inaccurate customer assessment, increasing the risk of loan defaults or rejecting eligible customers.
#
# - Financial institutions should therefore evaluate additional financial factors such as **annual income, outstanding debt, credit utilization ratio, repayment history, delayed payments, and credit inquiries** along with payment behaviour to improve the accuracy of credit risk assessment and reduce business risk.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Credit Mix vs Credit Score
plt.figure(figsize=(8, 6))

sns.countplot(
    data=data_copy,
    x='Credit_Mix',
    hue='Credit_Score',
    order=['Bad', 'Standard', 'Good'],
    hue_order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    edgecolor='black',
    linewidth=1
)

plt.title(
    "Credit Score Distribution Across Credit Mix",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Credit Mix", fontsize=12, fontweight='bold')
plt.ylabel("Number of Customers", fontsize=12, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.legend(title='Credit Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped countplot was chosen because both Credit_Mix and Credit_Score are categorical variables. It effectively compares the frequency of customers across different credit score categories within each credit mix category. This makes it easy to identify the relationship between a customer's credit mix and credit score and compare the distribution of customers among the different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights Found:-
#
# - Customers with a **Standard** credit mix have the highest number of **Standard** credit scores, indicating a strong association between a Standard credit mix and a Standard credit score.
#
# - Customers with a **Good** credit mix predominantly have **Good** credit scores, suggesting that maintaining a good credit mix is associated with better overall creditworthiness.
#
# - The **Bad** credit mix category contains the highest number of customers with **Poor** credit scores, indicating that customers with a poor credit mix are more likely to have lower credit scores.
#
# - The chart shows a clear relationship between **Credit Mix** and **Credit Score**, where better credit mix categories generally correspond to better credit scores.
#
# - Although a few customers with **Bad** or **Standard** credit mixes have **Good** credit scores, these are comparatively fewer, suggesting that **Credit Mix is an important factor influencing a customer's credit score, but it is not the only determining factor.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact?
#
# - The strong relationship between **Credit Mix** and **Credit Score** enables financial institutions to accurately segment customers based on their credit profiles and provide personalized financial products and services.
#
# - Customers with a **Standard** credit mix represent the largest customer segment. Financial institutions can focus on this group by offering credit improvement programs, financial education, and responsible lending strategies to improve their creditworthiness.
#
# - Customers with a **Good** credit mix can be identified for premium banking services, higher credit limits, lower interest rates, and exclusive financial products, helping improve customer satisfaction and profitability.
#
# - Customers with a **Bad** credit mix can be flagged for detailed credit risk assessment before approving loans or other financial services, helping reduce potential financial risk.
#
#
# ### Insights that lead to negative growth:-
#
# - A notable number of customers belong to the **Bad** credit mix category and also have **Poor** credit scores. This increases the risk of loan defaults, delayed repayments, and higher credit losses for financial institutions.
#
# - Although the relationship between **Credit Mix** and **Credit Score** is strong, a few customers with **Standard** or **Bad** credit mixes still have **Good** credit scores. Therefore, relying solely on credit mix for lending decisions may result in inaccurate customer assessment.
#
# - Financial institutions should evaluate additional factors such as **annual income, outstanding debt, repayment history, credit utilization ratio, and delayed payments** along with credit mix to make more accurate credit risk assessments and lending decisions.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Interest Rate vs Credit Score
sns.boxplot(
    data=data_copy,
    x='Credit_Score',
    y='Interest_Rate',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    linewidth=1.5,
    width=0.55,
)

plt.title(
    "Interest Rate Distribution Across Credit Score Categories",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Interest Rate", fontsize=12, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it effectively compares the distribution of Interest_Rate across different Credit_Score categories. It clearly displays the median interest rate, interquartile range (IQR), overall spread, and potential outliers for each credit score category, making it easier to compare interest rate patterns among customers with Poor, Standard, and Good credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights Found:-
#
# - Customers with a **Poor** credit score have the **highest median interest rate**, indicating that they are generally charged higher interest rates than customers in the other credit score categories.
#
# - Customers with a **Standard** credit score have a **moderate median interest rate** and a few high-interest-rate outliers, indicating some variability within this group.
#
# - Customers with a **Good** credit score have the **lowest median interest rate**, suggesting that they generally benefit from lower borrowing costs. However, this category contains several high-interest-rate outliers.
#
# - The presence of high-interest-rate outliers in the **Good** credit score category indicates that **interest rate alone does not determine a customer's credit score**. Other financial factors such as outstanding debt, repayment history, credit utilization ratio, annual income, and credit mix are also likely to influence a customer's overall creditworthiness.
#
# - Overall, the chart demonstrates an inverse relationship between **Interest Rate** and **Credit Score**, where customers with better credit scores generally receive lower interest rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact:-
#
# - The chart shows that customers with **Poor** credit scores generally have the highest interest rates. Financial institutions can identify these customers, perform a detailed credit risk assessment, and evaluate additional financial factors before approving loans or other financial services.
#
# - Customers with **Standard** credit scores and moderate interest rates form a large customer segment. Financial institutions can focus on this category by providing personalized financial products, credit improvement programs, and financial education to help improve their creditworthiness.
#
# - Customers with **Good** credit scores generally have lower interest rates, making them suitable candidates for premium banking services, higher credit limits, lower interest rates on future loans, and exclusive financial products after evaluating their overall financial profile.
#
# - The relationship between interest rate and credit score enables financial institutions to make better lending decisions and develop customer-specific financial strategies.
#
# ### Insights that lead to negative growth:-
#
# - Although customers with **Good** credit scores generally have the lowest interest rates, this category also contains several high interest rate outliers. This indicates that **interest rate alone is not sufficient to determine a customer's creditworthiness**.
#
# - Relying solely on interest rate while evaluating customers may result in inaccurate credit risk assessment and inappropriate lending decisions.
#
# - Financial institutions should therefore consider additional factors such as **annual income, outstanding debt, credit utilization ratio, repayment history, credit mix, and delayed payments** before approving loans or offering financial services.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Monthly Balance vs Credit Score
sns.boxplot(
    data=data_copy,
    x='Credit_Score',
    y='Monthly_Balance',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    linewidth=1.5,
    width=0.55,
)

plt.title(
    "Monthly Balance Distribution Across Credit Score Categories",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Monthly Balance", fontsize=12, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it effectively compares the distribution of Monthly_Balance across different Credit_Score categories. It clearly displays the median monthly balance, interquartile range (IQR), overall spread, and potential outliers for each credit score category, making it easier to compare monthly balance patterns among customers with Poor, Standard, and Good credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights
#
# - Customers with a **Good** credit score have the **highest median monthly balance**, indicating that they generally maintain higher remaining monthly balances than customers in the other credit score categories.
#
# - Customers with a **Standard** credit score have a **moderate monthly balance**, while customers with a **Poor** credit score have the **lowest median monthly balance** among the three categories.
#
# - All three credit score categories contain several high monthly balance outliers, suggesting that some customers maintain exceptionally high monthly balances regardless of their credit score.
#
# - The overall distribution indicates that **higher monthly balances are generally associated with better credit scores**. However, the presence of outliers across all categories suggests that **monthly balance alone is not sufficient to determine a customer's creditworthiness**, and other financial factors such as outstanding debt, repayment history, credit utilization ratio, and credit mix should also be considered.
#
# - The gradual increase in the median monthly balance from **Poor to Standard to Good** credit scores suggests a positive relationship between maintaining a healthier monthly balance and having a better credit profile.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact:-
#
# - The analysis shows that customers with **Good** credit scores generally maintain higher monthly balances. Financial institutions can identify these customers and offer premium banking services, higher credit limits, exclusive financial products, and loyalty programs.
#
# - Customers with **Standard** credit scores form an important customer segment with moderate monthly balances. Financial institutions can provide personalized financial planning, credit improvement programs, and budgeting guidance to help improve their creditworthiness.
#
# - Customers with **Poor** credit scores generally maintain lower monthly balances. These customers can be identified for detailed financial assessment and offered suitable repayment plans or financial counseling before extending additional credit facilities.
#
# - Understanding the relationship between monthly balance and credit score enables financial institutions to develop targeted customer strategies and make more informed lending decisions.
#
# ### Insights that lead to negative growth:-
#
# - The presence of high monthly balance outliers across all credit score categories indicates that **monthly balance alone is not sufficient to determine a customer's creditworthiness**.
#
# - Relying only on monthly balance when evaluating customers may result in inaccurate credit risk assessment, as customers with similar balances can still have different credit scores.
#
# - Financial institutions should therefore consider additional factors such as **annual income, outstanding debt, repayment history, credit utilization ratio, credit mix, delayed payments, and interest rate** before approving loans or providing financial services.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=data_copy,
    x='Credit_Score',
    y='Num_of_Loan',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    linewidth=1.5,
    width=0.55,
)

plt.title(
    "Number of Loans Distribution Across Credit Score Categories",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Number of Loans", fontsize=12, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it effectively compares the distribution of Num_of_Loan across different Credit_Score categories. It clearly displays the median number of loans, interquartile range (IQR), overall spread, and potential outliers for each credit score category, making it easier to compare loan distribution patterns among customers with Poor, Standard, and Good credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights:-
#
# - Customers with a **Poor** credit score have the **highest median number of loans**, indicating that they generally maintain more active loans than customers in the other credit score categories.
#
# - Customers with a **Standard** credit score have a **moderate number of loans**, with the median lower than that of the Poor credit score category.
#
# - Customers with a **Good** credit score generally have the **lowest number of loans**, suggesting that they tend to manage fewer active loans compared to the other categories.
#
# - Although customers with **Good** credit scores typically have fewer loans, a few high-value outliers are present. This indicates that **having a higher number of loans does not necessarily result in a poor credit score**, as other financial factors such as repayment history, outstanding debt, credit utilization ratio, annual income, and payment behaviour also influence a customer's overall creditworthiness.
#
# - Overall, the chart suggests that customers with fewer active loans generally tend to have better credit scores, although the number of loans alone is not sufficient to determine a customer's credit profile.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact:-
#
# - The chart enables financial institutions to segment customers based on both their **number of loans** and **credit score**, allowing them to design customer-specific lending and credit management strategies.
#
# - Customers with **Poor** credit scores generally have a higher number of active loans. These customers can be identified for detailed credit risk assessment before approving additional loans or other financial services.
#
# - Customers with **Standard** credit scores represent an important customer segment. Financial institutions can analyze the factors affecting their credit profile, provide financial education, personalized repayment plans, and credit improvement programs to help enhance their creditworthiness.
#
# - Customers with **Good** credit scores generally have fewer active loans and can be considered for premium financial products, higher credit limits, and exclusive banking services after evaluating their complete financial profile.
#
# - Overall, the analysis supports better customer segmentation, improved credit risk management, and more informed lending decisions.
#
#
# ### Insights that lead to negative growth:-
#
# - Although customers with **Good** credit scores generally have fewer loans, the presence of several high-loan outliers indicates that some customers maintain many active loans while still having good credit scores.
#
# - This suggests that the **number of loans alone should not be used to determine a customer's creditworthiness**. Relying solely on this factor may result in inaccurate lending decisions and increased financial risk.
#
# - Financial institutions should therefore evaluate additional factors such as **repayment history, outstanding debt, credit utilization ratio, annual income, payment behaviour, and credit mix** before approving loans or offering financial services.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Age vs Credit Score
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=data_copy,
    x='Credit_Score',
    y='Age',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    linewidth=1.5,
    width=0.55,
)

plt.title(
    "Age Distribution Across Credit Score Categories",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Age", fontsize=12, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it effectively compares the distribution of Age across different Credit_Score categories. It clearly displays the median age, interquartile range (IQR), overall spread, and potential outliers for each credit score category, making it easier to compare age distributions among customers with Poor, Standard, and Good credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights Found:-
#
# - Customers with a **Poor** credit score generally belong to the younger age group, with a lower median age compared to the other credit score categories.
#
# - Customers with a **Standard** credit score have a moderate median age, indicating that this group mainly consists of middle-aged customers.
#
# - Customers with a **Good** credit score have the highest median age among the three categories, suggesting that relatively older customers tend to have better credit scores.
#
# - The gradual increase in the median age from **Poor to Standard to Good** indicates a positive relationship between age and credit score. As customer age increases, credit scores generally tend to improve.
#
# - Although age appears to be associated with credit score, **age alone is not sufficient to determine a customer's creditworthiness**. Other financial factors such as annual income, repayment history, outstanding debt, credit utilization ratio, and payment behaviour also play an important role.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact:-
#
# - The analysis indicates that customers with **Good** credit scores generally belong to higher age groups. Financial institutions can use this information, along with other financial factors, to better assess customer creditworthiness and offer premium financial products, higher credit limits, and exclusive banking services.
#
# - Customers with **Standard** credit scores mainly belong to the middle-age group. Financial institutions can analyze additional financial factors, provide personalized financial guidance, and implement credit improvement programs to help these customers improve their credit profiles.
#
# - Customers with **Poor** credit scores generally belong to younger age groups. Financial institutions can perform detailed credit risk assessments, evaluate other financial indicators, and provide suitable financial products or educational programs before extending additional credit.
#
# - Overall, understanding the relationship between age and credit score helps financial institutions improve customer segmentation and make more informed lending decisions.
#
# ### Insights that lead to negative growth:-
#
# - **Age alone is not sufficient to determine a customer's creditworthiness.** Relying solely on age may lead to inaccurate customer assessment and inappropriate lending decisions.
#
# - Financial institutions should also consider important factors such as **annual income, outstanding debt, repayment history, credit utilization ratio, payment behaviour, credit mix, and number of loans** before approving loans or offering financial services.
#
# - Therefore, age should be treated as one of several factors in the credit evaluation process rather than the sole criterion for making financial decisions.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Credit Utilization Ratio vs Credit Score
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=data_copy,
    x='Credit_Score',
    y='Credit_Utilization_Ratio',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    linewidth=1.5,
    width=0.55,
)

plt.title(
    "Credit Utilization Ratio Distribution Across Credit Score Categories",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Credit Utilization Ratio", fontsize=12, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it effectively compares the distribution of Credit_Utilization_Ratio across different Credit_Score categories. It clearly displays the median credit utilization ratio, interquartile range (IQR), overall spread, and potential outliers for each credit score category, making it easier to compare utilization patterns among customers with Poor, Standard, and Good credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights:-
#
# - The median **Credit Utilization Ratio** is very similar across the **Poor**, **Standard**, and **Good** credit score categories, indicating only a small variation in utilization among the three groups.
#
# - The interquartile range (IQR) and overall spread are also similar across all credit score categories, suggesting that customers generally maintain comparable credit utilization ratios regardless of their credit score.
#
# - The **Standard** credit score category contains a few high utilization ratio outliers, while the **Poor** and **Good** categories show very few or no noticeable outliers.
#
# - The similarity in the distributions indicates that **Credit Utilization Ratio alone does not strongly differentiate customers based on their credit score**.
#
# - Overall, the chart suggests that although credit utilization is an important financial metric, it should be analyzed together with other factors such as **annual income, repayment history, outstanding debt, credit mix, number of loans, and payment behaviour** to accurately assess a customer's creditworthiness.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact:-
#
# - **Yes.** The analysis shows that the Credit Utilization Ratio is relatively similar across all credit score categories. This helps financial institutions understand that **credit utilization should not be used as the sole criterion** for assessing a customer's creditworthiness.
#
# - Financial institutions can combine the Credit Utilization Ratio with other important factors such as **annual income, repayment history, outstanding debt, credit mix, number of loans, and payment behaviour** to build a more accurate credit risk assessment model.
#
# - Since the utilization ratio is fairly consistent across all categories, institutions can focus on improving their overall customer evaluation process by considering multiple financial indicators rather than relying on a single metric.
#
# - A comprehensive assessment based on several financial factors can lead to better lending decisions, reduced credit risk, and improved customer segmentation.
#
# ### Insights that lead to negative growth:-
#
# - The chart indicates that **Credit Utilization Ratio alone does not clearly distinguish customers with Poor, Standard, and Good credit scores**. Therefore, relying solely on this metric may result in inaccurate customer assessment and inappropriate lending decisions.
#
# - The presence of similar utilization ratios across all credit score categories suggests that other financial factors have a significant influence on a customer's creditworthiness.
#
# - Financial institutions should avoid making lending or credit approval decisions based only on the Credit Utilization Ratio and should instead evaluate multiple financial indicators to minimize credit risk and improve decision-making.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Delay_from_due_date vs Credit Score
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=data_copy,
    x='Credit_Score',
    y='Delay_from_due_date',
    order=['Poor', 'Standard', 'Good'],
    palette='Set2',
    linewidth=1.5,
    width=0.55
)

plt.title(
    "Delay from Due Date Distribution Across Credit Score Categories",
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel("Credit Score", fontsize=12, fontweight='bold')
plt.ylabel("Delay from Due Date (Days)", fontsize=12, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it effectively compares the distribution of Delay_from_due_date across different Credit_Score categories. It clearly displays the median payment delay, interquartile range (IQR), overall spread, and potential outliers for each credit score category, making it easier to compare payment delay patterns among customers with Poor, Standard, and Good credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights:-
#
# - Customers with a **Poor** credit score have the **highest median delay from the due date**, indicating that they generally make payments later than customers in the other credit score categories.
#
# - Customers with a **Standard** credit score have a **moderate payment delay**, with a few high-delay outliers observed.
#
# - Customers with a **Good** credit score have the **lowest median delay from the due date**, suggesting that they generally make payments closer to the due date.
#
# - Although customers with **Good** credit scores typically have lower payment delays, this category contains several high-delay outliers. This indicates that **Delay_from_due_date alone is not sufficient to determine a customer's credit score**, as other financial factors such as annual income, outstanding debt, repayment history, credit utilization ratio, credit mix, and number of loans also influence overall creditworthiness.
#
# - Overall, the chart shows a clear relationship between **payment delays** and **credit scores**, where customers with shorter payment delays generally tend to have better credit scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Insights help create a positive business impact:-
#
# - **Yes.** The chart clearly distinguishes customers based on their **delay from the due date** and corresponding credit score, enabling financial institutions to perform better customer segmentation and credit risk assessment.
#
# - Customers with **Poor** credit scores generally have the highest payment delays. Financial institutions can identify these customers, perform a detailed assessment of their financial profile, and evaluate other influencing factors before approving loans or offering financial services.
#
# - Customers with **Standard** credit scores have moderate payment delays. Financial institutions can analyze the reasons behind these delays, provide financial education, personalized repayment plans, and credit improvement programs to help enhance their creditworthiness.
#
# - Customers with **Good** credit scores generally have the lowest payment delays. After evaluating their complete financial profile, financial institutions can offer premium financial products, higher credit limits, and exclusive banking services.
#
# - Overall, the analysis helps financial institutions improve lending decisions, customer segmentation, and credit risk management.
#
#
# ### Insights that lead to negative growth:-
#
# - The presence of outliers in the **Standard** and **Good** credit score categories indicates that **Delay_from_due_date alone is not sufficient to determine a customer's creditworthiness**.
#
# - Some customers with **Good** credit scores still have relatively high payment delays, suggesting that other financial factors also influence the overall credit score.
#
# - Therefore, financial institutions should evaluate additional factors such as **annual income, outstanding debt, repayment history, credit utilization ratio, credit mix, and number of loans** before approving loans or providing financial services. Relying only on payment delay may lead to inaccurate credit risk assessment and inappropriate lending decisions.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# select only required numerical columns
heatmap_data = data_copy[
    [
        'Age',
        'Annual_Income',
        'Monthly_Inhand_Salary',
        'Num_Bank_Accounts',
        'Num_Credit_Card',
        'Interest_Rate',
        'Num_of_Loan',
        'Delay_from_due_date',
        'Num_of_Delayed_Payment',
        'Changed_Credit_Limit',
        'Num_Credit_Inquiries',
        'Outstanding_Debt',
        'Credit_Utilization_Ratio',
        'Credit_History_Age',
        'Total_EMI_per_month',
        'Amount_invested_monthly',
        'Monthly_Balance'
    ]
]

# calculate correlation matrix
corr_matrix = heatmap_data.corr()

# plot heatmap
plt.figure(figsize=(18, 14))

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    square=True,
)

plt.title(
    "Correlation Heatmap of Numerical Features",
    fontsize=18,
    fontweight="bold",
    pad=20
)

plt.xticks(rotation=45, ha="right", fontsize=10)
plt.yticks(rotation=0, fontsize=10)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was chosen because it provides a comprehensive overview of the relationships among all numerical variables in the dataset. It clearly shows the strength and direction of correlations between features, helping identify strong positive or negative relationships, detect multicollinearity, and understand how different financial variables are associated with one another. This makes it easier to identify important patterns and supports more effective data analysis and decision-making.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights found from the chart:-
#
# - There is an almost perfect positive correlation (**1.00**) between **Annual Income** and **Monthly Inhand Salary**, indicating that customers with higher annual incomes generally have higher monthly salaries.
#
# - **Annual Income** also has a strong positive correlation with **Amount Invested Monthly (0.81)** and a moderate positive correlation with **Monthly Balance (0.63)**. This suggests that higher-income customers tend to invest more and maintain higher monthly balances.
#
# - **Outstanding Debt** shows a strong positive correlation with **Interest Rate (0.63)**, **Number of Loans (0.64)**, and **Number of Credit Inquiries (0.60)**. This indicates that customers with higher debt generally have more loans, higher interest rates, and make more credit inquiries.
#
# - **Credit History Age** has a strong negative correlation with **Outstanding Debt (-0.63)**, **Number of Loans (-0.61)**, and **Number of Credit Inquiries (-0.61)**. This suggests that customers with a longer credit history generally tend to have lower outstanding debt, fewer loans, and fewer credit inquiries.
#
# - **Credit Utilization Ratio** has very weak correlations with most numerical variables, indicating that it is relatively independent and should not be considered as the sole indicator of a customer's financial profile.
#
# - Overall, the heatmap shows that several financial variables are interrelated, while others have weak relationships. Therefore, customer creditworthiness should be assessed using multiple financial factors rather than relying on a single variable.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
pairplot_data = data_copy[
    [
        'Annual_Income',
        'Outstanding_Debt',
        'Interest_Rate',
        'Monthly_Balance',
        'Credit_Score'
    ]
]

sns.pairplot(
    pairplot_data,
    hue='Credit_Score',
    palette='Set2',
    diag_kind='hist',
    corner=True
)

plt.suptitle(
    "Pair Plot of Key Financial Variables by Credit Score",
    fontsize=18,
    fontweight='bold',
    y=1.02
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was chosen because it simultaneously visualizes the pairwise relationships and individual distributions of multiple numerical variables. It helps identify patterns, trends, clusters, correlations, and potential outliers while also showing how different credit score categories are distributed across key financial variables. This provides a comprehensive understanding of the relationships among the selected features in a single visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Insights found from the chart:-
#
# - The pair plot shows clear differences in the distribution of the selected financial variables across the three credit score categories, indicating that customer financial characteristics vary with credit score.
#
# - Customers with **Good** credit scores are generally concentrated in the **lower interest rate** range, while customers with **Poor** credit scores are more frequently associated with **higher interest rates**. Customers with **Standard** credit scores mostly fall between these two groups.
#
# - Customers with **Poor** credit scores tend to have **higher outstanding debt**, whereas customers with **Good** credit scores are more concentrated in the lower outstanding debt range.
#
# - **Annual Income** and **Monthly Balance** exhibit a positive relationship, suggesting that customers with higher incomes generally maintain higher monthly balances.
#
# - Although distinct patterns are visible among the credit score categories, there is some overlap between the **Poor**, **Standard**, and **Good** groups. This indicates that no single financial variable is sufficient to determine a customer's credit score.
#
# - Overall, the pair plot suggests that **annual income, outstanding debt, interest rate, and monthly balance collectively influence customer creditworthiness**, making a combination of financial variables more effective for assessing credit risk than relying on any single factor.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the exploratory data analysis, it is recommended that financial institutions adopt a comprehensive, data-driven approach to evaluate customer creditworthiness rather than relying on a single financial attribute.
#
# The analysis shows that factors such as **annual income, outstanding debt, interest rate, number of loans, delay from due date, monthly balance, credit history age, and credit mix** collectively influence a customer's credit score. Therefore, these variables should be considered together during the credit assessment process.
#
# Financial institutions should segment customers into **Poor**, **Standard**, and **Good** credit score categories and design personalized strategies for each group. Customers with **Poor** credit scores should undergo detailed risk assessment before loan approval. Customers with **Standard** credit scores should be provided with financial education, repayment support, and credit improvement programs to enhance their creditworthiness. Customers with **Good** credit scores can be offered premium financial products, higher credit limits, and exclusive banking services after proper verification.
#
# Additionally, the analysis indicates that no single feature is sufficient to determine a customer's creditworthiness. Hence, financial institutions should implement multi-factor credit evaluation models to improve decision-making, minimize default risk, and ensure more accurate lending decisions.
#
# Overall, these recommendations will help financial institutions improve customer segmentation, optimize credit risk management, reduce loan defaults, and achieve better business growth while enhancing customer satisfaction.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This Exploratory Data Analysis (EDA) project provided valuable insights into the factors influencing customer credit scores and overall financial behavior. Through data cleaning, visualization, and statistical analysis, meaningful patterns and relationships were identified among key financial variables.
#
# The analysis revealed that variables such as **annual income, outstanding debt, interest rate, number of loans, delay from due date, credit history age, monthly balance, and credit mix** have significant relationships with customer credit scores. Customers with **Good** credit scores generally exhibited lower outstanding debt, lower interest rates, fewer payment delays, and healthier financial profiles, while customers with **Poor** credit scores showed higher financial risk indicators. The **Standard** credit score category represented the largest customer segment, highlighting an opportunity for financial institutions to improve customer creditworthiness through targeted financial guidance and support.
#
# The correlation heatmap and pair plot further demonstrated that several financial variables are interrelated, emphasizing that **no single feature alone is sufficient to evaluate a customer's creditworthiness**. Instead, a combination of financial indicators should be considered for accurate credit assessment and lending decisions.
#
# Overall, this analysis enables financial institutions to better segment customers, improve credit risk management, personalize financial products, reduce loan default risk, and make more informed business decisions. The insights obtained from this EDA can serve as a strong foundation for developing predictive machine learning models for credit score classification in the future.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
